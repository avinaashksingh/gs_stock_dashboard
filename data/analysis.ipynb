# %% [markdown]
# # Data Analysis
#
# This notebook is for exploring and analyzing stock data.

# %%
import sys
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install matplotlib
import pandas as pd
import matplotlib.pyplot as plt

print("Libraries imported successfully.")
# Out:
# Requirement already satisfied: pandas in /Users/avinash/GS-Stock_Dashboard/venv/lib/python3.14/site-packages (3.0.1)
# Requirement already satisfied: numpy>=2.3.3 in /Users/avinash/GS-Stock_Dashboard/venv/lib/python3.14/site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/avinash/GS-Stock_Dashboard/venv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/avinash/GS-Stock_Dashboard/venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in /Users/avinash/GS-Stock_Dashboard/venv/lib/python3.14/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/avinash/GS-Stock_Dashboard/venv/lib/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/avinash/GS-Stock_Dashboard/venv/lib/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/avinash/GS-Stock_Dashboard/venv/lib/python3.14/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/avinash/GS-Stock_Dashboard/venv/lib/python3.14/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /Users/avinash/GS-Stock_Dashboard/venv/lib/python3.14/site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /Users/avinash/GS-Stock_Dashboard/venv/lib/python3.14/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/avinash/GS-Stock_Dashboard/venv/lib/python3.14/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/avinash/GS-Stock_Dashboard/venv/lib/python3.14/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/avinash/GS-Stock_Dashboard/venv/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/avinash/GS-Stock_Dashboard/venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Libraries imported successfully.

# %%
import os
for dirname, _, filenames in os.walk('.'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./gs_investing_com.csv
# ./gs_yahoo_finance.csv
# ./gs_barchart.csv
# ./analysis.ipynb
# ./gs_master_dataset.csv
# ./gs_nasdaq.csv
# ./gs_marketwatch.csv
